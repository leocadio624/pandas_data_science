# %%
import pandas as pd

# %%
df_estudiantes = pd.read_csv("estudiantes.csv")

# %%
df_estudiantes
# Out:
#     NOMBRE  EDAD GENERO       CARRERA SEMESTRE
# 0   VICTOR    28      M     AUDITORIA  PRIMERO
# 1   JOSEFA    23      F   INFORMATICA  PRIMERO
# 2     RAUL    26      M       DERECHO   QUINTO
# 3  MARIANA    27      F   INFORMATICA  SEPTIMO
# 4  RODRIGO    22      M       DERECHO  TERCERO
# 5  GUSTAVO    25      M  ARQUITECTURA  SEPTIMO
# 6     LUCY    23      F   INFORMATICA  PRIMERO
# 7    SOFIA    24      F      ECONOMIA   NOVENO

# %%
df.loc[1, 'CARRERA']
# Out:
# 'INFORMATICA'

# %%
df_estudiantes['TURNO'] = pd.Series(['tarde', 'noche', 'tarde', 'noche'])

# %%
df_estudiantes
# Out:
#     NOMBRE  EDAD GENERO       CARRERA SEMESTRE  TURNO
# 0   VICTOR    28      M     AUDITORIA  PRIMERO  tarde
# 1   JOSEFA    23      F   INFORMATICA  PRIMERO  noche
# 2     RAUL    26      M       DERECHO   QUINTO  tarde
# 3  MARIANA    27      F   INFORMATICA  SEPTIMO  noche
# 4  RODRIGO    22      M       DERECHO  TERCERO    NaN
# 5  GUSTAVO    25      M  ARQUITECTURA  SEPTIMO    NaN
# 6     LUCY    23      F   INFORMATICA  PRIMERO    NaN
# 7    SOFIA    24      F      ECONOMIA   NOVENO    NaN

# %%
semestre = df_estudiantes.pop('SEMESTRE')

# %%
df_estudiantes
# Out:
#     NOMBRE  EDAD GENERO       CARRERA  TURNO
# 0   VICTOR    28      M     AUDITORIA  tarde
# 1   JOSEFA    23      F   INFORMATICA  noche
# 2     RAUL    26      M       DERECHO  tarde
# 3  MARIANA    27      F   INFORMATICA  noche
# 4  RODRIGO    22      M       DERECHO    NaN
# 5  GUSTAVO    25      M  ARQUITECTURA    NaN
# 6     LUCY    23      F   INFORMATICA    NaN
# 7    SOFIA    24      F      ECONOMIA    NaN

# %%
#agregamos una tupla al data frame
df_estudiantes = df_estudiantes.append(pd.Series(['Carlos', 27, 'M', 'Sociologia', 'tarde '], index = ['NOMBRE', 'EDAD', 'GENERO', 'CARRERA', 'TURNO']), ignore_index = True )
# Out:
# C:\Users\hsu\AppData\Local\Temp\ipykernel_7512\1263878588.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_estudiantes = df_estudiantes.append(pd.Series(['Carlos', 27, 'M', 'Sociologia', 'tarde '], index = ['NOMBRE', 'EDAD', 'GENERO', 'CARRERA', 'TURNO']), ignore_index = True )

# %%
df_estudiantes
# Out:
#     NOMBRE  EDAD GENERO       CARRERA   TURNO
# 0   VICTOR    28      M     AUDITORIA   tarde
# 1   JOSEFA    23      F   INFORMATICA   noche
# 2     RAUL    26      M       DERECHO   tarde
# 3  MARIANA    27      F   INFORMATICA   noche
# 4  RODRIGO    22      M       DERECHO     NaN
# 5  GUSTAVO    25      M  ARQUITECTURA     NaN
# 6     LUCY    23      F   INFORMATICA     NaN
# 7    SOFIA    24      F      ECONOMIA     NaN
# 8   Carlos    27      M    Sociologia  tarde
# 9   Carlos    27      M    Sociologia  tarde

# %%
#df_estudiantes = df_estudiantes.drop(8)
df_estudiantes = df_estudiantes.drop([8, 12])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [41], in <cell line: 2>()
#       1 #df_estudiantes = df_estudiantes.drop(8)
# ----> 2 df_estudiantes = df_estudiantes.drop([8, 12])
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
# ...

# %%
df_estudiantes
# Out:
#      NOMBRE  EDAD GENERO       CARRERA   TURNO
# 0    VICTOR    28      M     AUDITORIA   tarde
# 1    JOSEFA    23      F   INFORMATICA   noche
# 2      RAUL    26      M       DERECHO   tarde
# 3   MARIANA    27      F   INFORMATICA   noche
# 4   RODRIGO    22      M       DERECHO     NaN
# 5   GUSTAVO    25      M  ARQUITECTURA     NaN
# 6      LUCY    23      F   INFORMATICA     NaN
# 7     SOFIA    24      F      ECONOMIA     NaN
# 9    Carlos    27      M    Sociologia  tarde
# 10   Carlos    27      M    Sociologia  tarde
# 11   Carlos    27      M    Sociologia  tarde

# %%
df = df_estudiantes

# %%
df_filtrado = df[ (df['GENERO'] == 'F') & (df['EDAD'] >= 22) ]

# %%
df_filtrado
# Out:
#     NOMBRE  EDAD GENERO      CARRERA  TURNO
# 1   JOSEFA    23      F  INFORMATICA  noche
# 3  MARIANA    27      F  INFORMATICA  noche
# 6     LUCY    23      F  INFORMATICA    NaN
# 7    SOFIA    24      F     ECONOMIA    NaN

# %%
#df_restantes = df.drop( df[['GENERO'] == 'F') & (df['EDAD'] >= 22)] )

df_restantes = df.drop(df[ (df.GENERO == 'F' ) & (df.EDAD >= 22) ].index)

#df_restantes = df.drop(df[(df.score < 50) & (df.score > 20)].index)

# %%
df_restantes
# Out:
#      NOMBRE  EDAD GENERO       CARRERA   TURNO
# 0    VICTOR    28      M     AUDITORIA   tarde
# 2      RAUL    26      M       DERECHO   tarde
# 4   RODRIGO    22      M       DERECHO     NaN
# 5   GUSTAVO    25      M  ARQUITECTURA     NaN
# 9    Carlos    27      M    Sociologia  tarde
# 10   Carlos    27      M    Sociologia  tarde
# 11   Carlos    27      M    Sociologia  tarde

# %%
df_restantes = df_restantes.reset_index(drop=True)

# %%
df_restantes
# Out:
#     NOMBRE  EDAD GENERO       CARRERA   TURNO
# 0   VICTOR    28      M     AUDITORIA   tarde
# 1     RAUL    26      M       DERECHO   tarde
# 2  RODRIGO    22      M       DERECHO     NaN
# 3  GUSTAVO    25      M  ARQUITECTURA     NaN
# 4   Carlos    27      M    Sociologia  tarde
# 5   Carlos    27      M    Sociologia  tarde
# 6   Carlos    27      M    Sociologia  tarde

# %%
df.sort_values('EDAD')
# Out:
#      NOMBRE  EDAD GENERO       CARRERA   TURNO
# 4   RODRIGO    22      M       DERECHO     NaN
# 1    JOSEFA    23      F   INFORMATICA   noche
# 6      LUCY    23      F   INFORMATICA     NaN
# 7     SOFIA    24      F      ECONOMIA     NaN
# 5   GUSTAVO    25      M  ARQUITECTURA     NaN
# 2      RAUL    26      M       DERECHO   tarde
# 3   MARIANA    27      F   INFORMATICA   noche
# 9    Carlos    27      M    Sociologia  tarde
# 10   Carlos    27      M    Sociologia  tarde
# 11   Carlos    27      M    Sociologia  tarde
# 0    VICTOR    28      M     AUDITORIA   tarde
